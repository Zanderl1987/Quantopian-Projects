# %% [markdown]
# Run the cell below to create your tear sheet.

# %%
bt = get_backtest('5b5cfefe9d8a1f43944e1a92')
bt.create_full_tear_sheet()
# Out:
# 100% Time: 0:00:01|###########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-01-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2018-07-27</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>30</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>8.7%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>23.8%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>20.5%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.47</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.66</td>
#     </tr>
#     <tr>
# ...
