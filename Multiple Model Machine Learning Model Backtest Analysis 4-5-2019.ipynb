# %%
bt = get_backtest('5b6a345c887d23439fe648b0')
bt.create_full_tear_sheet()
# Out:
# 100% Time: 0:00:02|###########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2010-01-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2018-08-06</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>102</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>15.7%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>248.4%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>22.1%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.77</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.50</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.80</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# Decided to keep the bayesian tear sheet even though it through an error. The important thing that I was most interested in was the chart that populated.
#
# Note that the forward values from the out of sample (OOS) data are better than the backtest values. While this is somewhat suspicious, it is still a good sign because those numbers aren't significantly better. Regardless, it will require some additional investigation before we can feel comfortable with the values.

# %%
bt.create_bayesian_tear_sheet(live_start_date='2017-01-01',return_fig=True,stoch_vol=True)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using ADVI...
# Running T model
# Average Loss = -5,714.2:  23%|██▎       | 45761/200000 [00:30<01:42, 1500.90it/s]
# Convergence archived at 45900
# Interrupted at 45,900 [22%]: Average Loss = -2,793.3
# ...
# 100%|██████████| 2000/2000 [00:00<00:00, 2746.12it/s]
# Finished T model (required 43.04 seconds).
#
# Running BEST model
# Auto-assigning NUTS sampler...
# Initializing NUTS using ADVI...
# Average Loss = -7,069.3:  24%|██▎       | 47291/200000 [00:33<01:48, 1405.91it/s]
# Convergence archived at 47400
# Interrupted at 47,400 [23%]: Average Loss = -3,518.6
# 100%|██████████| 2500/2500 [00:07<00:00, 350.44it/s]
# Finished BEST model (required 53.93 seconds).
#
# Finished plotting Bayesian cone (required 0.36 seconds).
#
# Finished plotting BEST results (required 0.93 seconds).
#
# Finished computing Bayesian predictions (required 0.13 seconds).
#
# Finished plotting Bayesian VaRs estimate (required 0.05 seconds).
#
# ...
